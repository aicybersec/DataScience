# %%
#https://www.kaggle.com/ronitf/heart-disease-uci

import gradio as gr

# %%
def inference(age, sex, ch, cardio):
    s = 0 if sex=='female' else 1
    df = pd.DataFrame([[age, s, ch, cardio]], 
                      columns=['Age', 'Sex', 'Cholestoral (in mg/dl)', 
                               'Resting electrocardiographic results'])
    df = st.transform(df)
    pred = trainedmodel.predict_proba(df)[0]
    res = {'No Heart Desease': pred[0], 'Has Heart Desease': pred[1]}
    return res

sex = gr.inputs.Radio(['female', 'male'], label="Sex")
age = gr.inputs.Slider(minimum=1, maximum=100, default=22, label="Age")
ch = gr.inputs.Slider(minimum=120, maximum=560, default=200, label="Cholestoral (in mg/dl)")
cardio = gr.inputs.Radio([0, 1, 2], label="Resting electrocardiographic results")

gr.Interface(inference, [age, sex, ch, cardio], "label", live=True).launch(share=True) #, debug=True Use in Colab
# Out:
# Running locally at: http://127.0.0.1:7882/
# This share link will expire in 24 hours. If you need a permanent link, visit: https://gradio.app/introducing-hosted (NEW!)
# Running on External URL: https://17280.gradio.app
# Interface loading below...
#         <iframe
#             width="900"
#             height="500"
#             src="https://17280.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<Flask 'gradio.networking'>,
#  'http://127.0.0.1:7882/',
#  'https://17280.gradio.app')
# [2021-09-12 11:30:19,350] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,373] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,383] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,390] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,397] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,415] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,425] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,446] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,466] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,473] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,480] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,487] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,494] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,501] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,515] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,523] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,536] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,590] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,606] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,626] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,633] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,640] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,647] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,654] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,661] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:19,718] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
# ...
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:33,406] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:33,413] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:33,420] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:33,434] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:33,442] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:44,020] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:49,979] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
# [2021-09-12 11:30:51,970] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 92, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 334, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\Lenovo\anaconda3\lib\site-packages\gradio\interface.py", line 307, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-f9d94fe16654>", line 3, in inference
#     df = pd.DataFrame([[age, s, ch, cardio]],
# NameError: name 'pd' is not defined
